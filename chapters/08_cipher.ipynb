# HcoAJWG9S3xePMTp28B/6xwararzTNRvZydtegcPUY0IIc+f3ljVRXv1ZvpZk+yW
# mu27jjCwYszRt53ULI1SUNxs9R+FL7ewHvQj8qN6ASqO7NRLFSr/DOjukCZ5lr38
# ibgjmZHnpjikI0AO51dQRnB+/EI4KU3tX0WdR0aBAoGBAIySv4OKW13ejnCb3BAO
# ltugu+lsf8acfK8YU+AhzsqBSx1AhlS6qK40sGfrXrkCCWZUNeogDYcNGYRELg7e
# +sZjRc/0K7aVrZfY7fcTZK5mP/J0Njfiu6yY908QBECWANzQieEXCcbZMIaPJq2J
# s3DrKeTsM/8dPEwxKlUJojW4
# -----END PRIVATE KEY-----

# %%
#(2) ボブが公開鍵を公開する．

#(3) アリスがボブの公開鍵を手に入れる．

#(4) アリスがボブの公開鍵を使ってメッセージを暗号化し，ボブに送る．

#(4.1) メッセージをファイルに書く．
# !printf "こんにちは\n" > message4bob

#(4.2) ボブの公開鍵を使って暗号文を作る．
# !openssl pkeyutl -encrypt -pubin -inkey bob-public.pem -in message4bob -out message4bob-secret
# !base64 message4bob-secret
# Out:
# cXWNWmGPTa/9wL2TnaIsldqqnlGzQOLuNMHxV1Ivh2CyiTaSNI9S7AQNw3O4rD6BEFH0sILfKdAE
# MGC6C+eq7Qqn4Px7kTIILk2GhlGo/6y7gg9jFeg1lo30dFXm5Vbff8Vwug5a6ygyLoD1EM7SMVTu
# rzJvJNmiVNB7VQba0kAJLm93nkzxlWMVE73QPAH+91bkPe6KZl91cvyeY9oNIhLvYByfy2yHIMrF
# kzha++ZK5Hx7v+FbJLQDZlhfIFEBpep+xhV3hjORBR9VUgA+uHXZRcBN/v2yf9+KyoEii24Qlwz3
# qol0IHM/tV9HUjNiurBtW+/PY8YQUCil5WiAsA==

# %%
#(5) ボブが暗号文を受け取り，秘密鍵を使って復号する．
# !openssl pkeyutl -decrypt -inkey bob-private.pem -in message4bob-secret
# Out:
# こんにちは

# %%
# !wget https://raw.githubusercontent.com/taroyabuki/LI/refs/heads/main/yabuki-public.pem
# Out:
# --2026-06-18 16:00:03--  https://raw.githubusercontent.com/taroyabuki/LI/refs/heads/main/yabuki-public.pem
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451 [text/plain]
# Saving to: ‘yabuki-public.pem’
#
# yabuki-public.pem   100%[===================>]     451  --.-KB/s    in 0s
#
# 2026-06-18 16:00:04 (5.40 MB/s) - ‘yabuki-public.pem’ saved [451/451]

# %%
# !printf "26g3115" > report

# %%
# !cat report
# Out:
# 26g3115

# %%
# !openssl pkeyutl -encrypt -pubin -inkey yabuki-public.pem -in report -out report-secret
# !base64 report-secret
# Out:
# V0Kw5y71WL0DCUkKL3f8T9BXTr/h/Gn87T36CiH8/qdSvHPAzQiT3bQtsTCR9Y4GdFAFL2NDwLfq
# GlZO6JmfKLCKcLypYIYohgSzWlvkYf+Da7BLFNNlDNjk/7KqbuSGxV2M9X/E7Uw/IqOXZBykFZcs
# IoC3xNCXUR6fdJt9x7glq5X7zIax++zLJdhPtrRiMv8lAojsAF+ZYmOUP2+nc2owXt6guOgCouo2
# mdlZ/fWrawU64MJzFXXifdQr4HtrqHMfGzpqgHYM6fXs4vdb0elsnJw5IMC6S3HYUeGip2mOgZsO
# eFUkK60K4Y2Qh4EiuDRx3/B+VVxt9tAsPtgKyw==

# %%
# !printf "26g3115" > report

# %%
# !cat report-secret
# Out:
# WB��.�X�	I
# /w�O�WN���i��=�
# �ݴ-�0���tP/cC���VN號(��p��`�(��Z[�a��k�K�e�����n��]����L?"��d��,"���ЗQ�t�}Ǹ%���̆����%�O��b2�%��_�bc�?o�sj0^ޠ����6��Y���k:��su�}�+�{k�s:j�v�����[��l��9 ��Kq�Qᢧi���xU$+�
# ፐ��"�4q��~U\m��,>�

# %% [markdown]
# ### 8.3.2 デジタル署名
#
# アリスはアリスの秘密鍵でデジタル署名を作り，ボブはアリスの公開鍵でデジタル署名を検証します．
#
# ファイル|役割
# --|--
# alice-public.pem|アリスの公開鍵
# alice-private.pem|アリスの秘密鍵
# alice-message|アリスのメッセージ
# alice-message-signature|アリスのデジタル署名

# %% [markdown]
# #### デジタル署名

# %%
#(1) アリスが公開鍵と秘密鍵を作る．
# !openssl genrsa -out alice-private.pem 2048
# !openssl rsa -in alice-private.pem -pubout -out alice-public.pem
# Out:
# writing RSA key

# %%
#(2) アリスがメッセージをファイルに書き，アリスが秘密鍵を使ってデジタル署名を作る．
# !printf "HELLO\n" > alice-message
# !openssl dgst -sha256 -sign alice-private.pem -out alice-message-signature alice-message

# %%
#(3) アリスが公開鍵を公開する．

#(4) ボブがアリスの公開鍵，メッセージ，デジタル署名を取得する．

#(5) ボブがアリスの公開鍵を使って，メッセージのデジタル署名を検証する．
# !openssl dgst -sha256 -verify alice-public.pem -signature alice-message-signature alice-message
# Out:
# Verified OK

# %% [markdown]
# ### 8.3.3 デジタル証明書

# %% [markdown]
# ## 8.4 ウェブの安全性

# %% [markdown]
# ### 8.4.1 TLS
